# %%
from keras.models import Sequential
model = Sequential()
# Out:
# Using TensorFlow backend.
# C:\Users\harveen_chadha\AppData\Local\Continuum\Miniconda3\envs\carnd-term1\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Load pickled data
import pickle
import numpy as np
import tensorflow as tf
#tf.python.control_flow_ops = tf

with open('small_train_traffic.p', mode='rb') as f:
    data = pickle.load(f)

X_train, y_train = data['features'], data['labels']

# Initial Setup for Keras
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import Adam

# TODO: Build the Final Test Neural Network in Keras Here
model = Sequential()
model.add(Convolution2D(6,5,5,border_mode='valid',input_shape=(32,32,3)))
model.add(Activation('relu'))
model.add(Convolution2D(12,3,3,border_mode='same', input_shape=(28,28,6)))

model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Activation('relu'))
model.add(Convolution2D(24,5,5, border_mode='same',input_shape=(14,14,12)))

model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Activation('relu'))
model.add(Flatten(input_shape=(7,7,24)))
model.add(Dense(588))

model.add(Dropout(0.5))
model.add(Activation('relu'))
model.add(Dense(294))
model.add(Dropout(0.5))
model.add(Activation('relu')) 

model.add(Dense(100))
model.add(Dropout(0.5))
model.add(Activation('relu')) 

model.add(Dense(5))
model.add(Activation('softmax'))
# preprocess data
X_normalized = np.array(X_train / 255.0 - 0.5 )

from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y_one_hot = label_binarizer.fit_transform(y_train)

Adam(lr=25)
model.compile('adam', 'categorical_crossentropy', ['accuracy'])
history = model.fit(X_normalized, y_one_hot, nb_epoch=50, validation_split=0.2)

with open('small_test_traffic.p', 'rb') as f:
    data_test = pickle.load(f)

X_test = data_test['features']
y_test = data_test['labels']

# preprocess data
X_normalized_test = np.array(X_test / 255.0 - 0.5 )
y_one_hot_test = label_binarizer.fit_transform(y_test)

print("Testing")

# TODO: Evaluate the test data in Keras Here
metrics = model.evaluate(X_normalized_test,y_one_hot_test)
# TODO: UNCOMMENT CODE
#for metric_i in range(len(model.metrics_names)):
#    metric_name = model.metrics_names[metric_i]
#    metric_value = metrics[metric_i]
#    print('{}: {}'.format(metric_name, metric_value))
# Out:
# Train on 80 samples, validate on 20 samples
# Epoch 1/50
# 80/80 [==============================] - 1s - loss: 1.5499 - acc: 0.2750 - val_loss: 1.2749 - val_acc: 0.3000
# Epoch 2/50
# 80/80 [==============================] - 0s - loss: 1.4507 - acc: 0.2375 - val_loss: 1.1492 - val_acc: 0.4000
# Epoch 3/50
# 80/80 [==============================] - 0s - loss: 1.3280 - acc: 0.3250 - val_loss: 1.1528 - val_acc: 0.5000
# Epoch 4/50
# 80/80 [==============================] - 0s - loss: 1.2642 - acc: 0.4625 - val_loss: 1.0833 - val_acc: 0.7000
# Epoch 5/50
# 80/80 [==============================] - 0s - loss: 1.2492 - acc: 0.5000 - val_loss: 0.9902 - val_acc: 0.7000
# Epoch 6/50
# 80/80 [==============================] - 0s - loss: 1.2893 - acc: 0.4750 - val_loss: 0.9386 - val_acc: 0.7000
# Epoch 7/50
# 80/80 [==============================] - 0s - loss: 1.1513 - acc: 0.5125 - val_loss: 0.8988 - val_acc: 0.6500
# Epoch 8/50
# Epoch 30/50
# 80/80 [==============================] - 0s - loss: 0.2922 - acc: 0.8250 - val_loss: 0.1810 - val_acc: 1.0000
# Epoch 31/50
# 80/80 [==============================] - 0s - loss: 0.2951 - acc: 0.8500 - val_loss: 0.1825 - val_acc: 0.9500
# Epoch 32/50
# 80/80 [==============================] - 0s - loss: 0.3234 - acc: 0.8125 - val_loss: 0.1793 - val_acc: 0.9500
# Epoch 33/50
# 80/80 [==============================] - 0s - loss: 0.3213 - acc: 0.8500 - val_loss: 0.1667 - val_acc: 1.0000
# Epoch 34/50
# 80/80 [==============================] - 0s - loss: 0.3321 - acc: 0.8250 - val_loss: 0.1639 - val_acc: 0.9500
# Epoch 35/50
# 80/80 [==============================] - 0s - loss: 0.3055 - acc: 0.8375 - val_loss: 0.1881 - val_acc: 0.9000
# Epoch 36/50
# 80/80 [==============================] - 0s - loss: 0.3155 - acc: 0.8500 - val_loss: 0.2187 - val_acc: 0.8500
# Epoch 37/50
# 80/80 [==============================] - 0s - loss: 0.5734 - acc: 0.6750 - val_loss: 0.2095 - val_acc: 0.8500
# Epoch 38/50
# 80/80 [==============================] - 0s - loss: 0.3244 - acc: 0.8375 - val_loss: 0.2061 - val_acc: 0.8500
# Epoch 39/50
# 80/80 [==============================] - 0s - loss: 0.3346 - acc: 0.7625 - val_loss: 0.2073 - val_acc: 0.8500
# Epoch 40/50
# 80/80 [==============================] - 0s - loss: 0.3224 - acc: 0.8125 - val_loss: 0.2086 - val_acc: 0.8500
# Epoch 41/50
# 80/80 [==============================] - 0s - loss: 0.3059 - acc: 0.8750 - val_loss: 0.2040 - val_acc: 0.8500
# Epoch 42/50
# 80/80 [==============================] - 0s - loss: 0.2976 - acc: 0.8375 - val_loss: 0.1955 - val_acc: 0.8500
# Epoch 43/50
# 80/80 [==============================] - 0s - loss: 0.2962 - acc: 0.8375 - val_loss: 0.1839 - val_acc: 0.8500
# Epoch 44/50
# 80/80 [==============================] - 0s - loss: 0.2987 - acc: 0.8125 - val_loss: 0.1682 - val_acc: 0.8500
# Epoch 45/50
# 80/80 [==============================] - 0s - loss: 0.3773 - acc: 0.8250 - val_loss: 0.1645 - val_acc: 0.8500
# Epoch 46/50
# 80/80 [==============================] - 0s - loss: 0.2954 - acc: 0.8500 - val_loss: 0.1800 - val_acc: 0.9000
# Epoch 47/50
# 80/80 [==============================] - 0s - loss: 0.3283 - acc: 0.8250 - val_loss: 0.1956 - val_acc: 0.8500
# Epoch 48/50
# 80/80 [==============================] - 0s - loss: 0.3135 - acc: 0.8000 - val_loss: 0.1824 - val_acc: 0.9500
# Epoch 49/50
# 80/80 [==============================] - 0s - loss: 0.2811 - acc: 0.8375 - val_loss: 0.1773 - val_acc: 0.8500
# Epoch 50/50
# 80/80 [==============================] - 0s - loss: 0.2565 - acc: 0.8250 - val_loss: 0.1768 - val_acc: 0.8500
# Testing
# 20/20 [==============================] - 0s
